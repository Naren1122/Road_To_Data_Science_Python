# %%
import json

# create json data
details = [
    {
        "users": [
            {
                "id": 1,
                "name": "Alice Johnson",
                "email": "alice@example.com",
                "age": 28,
                "isActive": True,
                "roles": ["admin", "editor"],
                "address": {
                    "street": "123 Main St",
                    "city": "New York",
                    "country": "USA"
                }
            },
            {
                "id": 2,
                "name": "Bob Smith",
                "email": "bob@example.com",
                "age": 34,
                "isActive": False,
                "roles": ["viewer"],
                "address": {
                    "street": "456 Oak Ave",
                    "city": "Chicago",
                    "country": "USA"
                }
            },
            {
                "id": 3,
                "name": "Charlie Brown",
                "email": "charlie@example.com",
                "age": 25,
                "isActive": True,
                "roles": ["editor"],
                "address": {
                    "street": "789 Pine Rd",
                    "city": "San Francisco",
                    "country": "USA"
                }
            }
        ],
        "metadata": {
            "totalUsers": 3,
            "generatedAt": "2026-06-10T12:00:00Z"
        }
    }
]

# write json file
with open('details.json', 'w') as file:
    json.dump(details, file, indent=4)

# read json file
with open('details.json', 'r') as file:
    data = json.load(file)

# display data
for row in data:
   
    for key, value in row.items():
      print(f"{key}: {value}")
# Out:
# users: [{'id': 1, 'name': 'Alice Johnson', 'email': 'alice@example.com', 'age': 28, 'isActive': True, 'roles': ['admin', 'editor'], 'address': {'street': '123 Main St', 'city': 'New York', 'country': 'USA'}}, {'id': 2, 'name': 'Bob Smith', 'email': 'bob@example.com', 'age': 34, 'isActive': False, 'roles': ['viewer'], 'address': {'street': '456 Oak Ave', 'city': 'Chicago', 'country': 'USA'}}, {'id': 3, 'name': 'Charlie Brown', 'email': 'charlie@example.com', 'age': 25, 'isActive': True, 'roles': ['editor'], 'address': {'street': '789 Pine Rd', 'city': 'San Francisco', 'country': 'USA'}}]
# metadata: {'totalUsers': 3, 'generatedAt': '2026-06-10T12:00:00Z'}

# %%
#append data in json
with open('details.json', 'a') as file:
    data.append(new_data)
    json.dump(data, file, indent=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 #append data in json
#       2 with open('details.json', 'a') as file:
# ----> 3     data.append(new_data)
#       4     json.dump(data, file, indent=4)
#
# NameError: name 'new_data' is not defined
