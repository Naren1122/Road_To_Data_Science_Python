# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('csv', data_files='data_jobs.csv')
# Out:
# Found cached dataset csv (C:/Users/user/.cache/huggingface/datasets/csv/default-67adf8ac8541e0f7/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df = dataset["train"].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
#searching if there is brazil in csv file
df['job_country'].isin(['Brazil']).any()
# Out:
# True

# %%
us_jobs = df[df['job_country']]
