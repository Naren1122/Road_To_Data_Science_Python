# %%
import numpy as np
import pandas as pd

# %%
employees = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 28],
    "city": ["New York", "Chicago", "Boston"],
    "salary": [75000, 82000, 69000]
}

# %%
df = pd.DataFrame(employees)
df

# %%
data = [
    ["Alice",25,"New York",75000],
    ["Bob",30,"Chicago",82000],
    ["Charlie",28,"Boston",69000]
]
df2 = pd.DataFrame(data) # columns will not be printed for array
df2

# %%
columns = ["Name","Age","City","salary"] # to print with columns for an array
df2 = pd.DataFrame(data,columns = columns)
df2

# %%
# SELECTING AND INDEXINF A COLUMNS.......................

# %%
df2[["Name","City"]] # for dataframe u will need to keep column name in square bracket[]

# %%
# CREATING A NEW COLUMNS ..................................

# %%
df2["Designation"] = ["doctor","IT_Expert","UI/UX"]
df2

# %%
df2.drop('Designation',axis = 1) # it does not remove from original data

# %%
df2

# %%
df2.drop('Designation',axis = 1,inplace = True) # now it removes from main data
df2

# %%
df2.drop(["City","salary"],axis = 1, inplace = True)
df2

# %%
# selecting row >..............................................

# %%
df2[0]
# Out:
# Error:

# %%
df2.loc[0]

# %%
df2.loc[[0,1]]

# %%
df.iloc[[2,1]]

# %%
df.loc[[0,1]][["city","salary"]] # suppiose u want cuty and salary of ity and salary of 0 and 1

# %%
#Conditional Selection -----------------------------------------------------

# %%
# i only want to see whose age is above 30
df2[df2["Age"]<30]

# %%
df2[(df2["Age"]<30)  & (df2["City"] == "Paris")]
