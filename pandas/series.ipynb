# %%
'''
use case of pandas

- data cleaning
- data analysis
- data transformation
- data visualization
- data aggregation
- file handling
- data filtering
- time series analysis
'''
# Out:
# '\nuse case of pandas\n\n- data cleaning\n- data analysis\n- data transformation\n- data visualization\n- data aggregation\n- file handling\n- data filtering\n- time series analysis\n'

# %%
#pandas series ...........................................

# %%
import pandas as pd
import numpy as np

# %%
labels = ['a','b','c']
mylists = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(mylists)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
 pd.Series(mylists,index=labels) # will have a b c as index insted of  012
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
