# %%
'''
--update data

--update table_name set column_name ='value' where pk=value;

update Customers set customer_name = 'Peter Parker' where customer_id = 5;


--changing column name
-- alter table customers rename phone to customer_phone;

-- to remove whole structure (table, column, database)
--drop


----cascade,set null, no action for data manipulation  delete
-- #difference between truncate and delete

-- Analysis ----> AND (for numeric to filter range of data) , OR (categorical record to filter category 
of data)




'''
