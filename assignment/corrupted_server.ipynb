# %%
raw_logs = [45, "TIMEOUT", 120, "", 88, "ERROR_99"]


for log in raw_logs:
    try:
        log_time = int(log)   # Try converting to integer
        print(f"Processing log: {log_time} ms")
    
    except ValueError:
        print("Skipping corrupted entry")
        continue
# Out:
# Processing log: 45 ms
# Skipping corrupted entry
# Processing log: 120 ms
# Skipping corrupted entry
# Processing log: 88 ms
# Skipping corrupted entry
