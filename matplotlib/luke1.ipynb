# %%
import pandas as pd
from datasets import load_dataset

# Added 'r' at the start and '.csv' at the end
dataset = load_dataset('csv', data_files=r'C:\Users\user\Downloads\data_jobs.csv')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# Found cached dataset csv (C:/Users/user/.cache/huggingface/datasets/csv/default-4d48691ae21c8a8f/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
import numpy as np
