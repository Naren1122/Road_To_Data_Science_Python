# %%
import pandas as pd
from datasets import load_dataset

# Corrected file path - use the full absolute path to your CSV file
# Replace this path with the actual location of your data_jobs.csv file
dataset = load_dataset('csv', data_files=r'C:\Users\Lotus\Desktop\python\matplotlib\data_jobs.csv')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#simple code

x = [1,2,3,4]
y = [1,2,3,4]

plt.plot(x,y)
plt.title("Simple Line Plot")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show()

# %%
df.job_posted_date.head()

# %%
plt.plot(df.job_posted_date,df.job_posted_date)

# %%
date_counts = df.job_posted_date.value_counts()
date_counts =date_counts.sort_index()
date_counts

# %%
type(date_counts)

# %%
df['job_posted_month'] = df['job_posted_date'].dt.month

# %%
monthly_counts = df['job_posted_month'].value_counts()
monthly_counts = monthly_counts.sort_index()
monthly_counts

# %% [markdown]
# plt.plot(monthly_counts.index, monthly_counts.values)

# %%
plt.show()

# %%
#making bar charts................................................................

# %%
job_counts = df.job_title.value_counts().head(3)
job_counts

# %%
# plt.bar(job_counts.index, job_counts.values)
# plt.show                     or

job_counts.plot(kind='bar')
plt.show()
