# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/Fraud Detection Dataset.csv')

# %%
df.head()
# Out:
#   Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0             T1     4174             1292.76   ATM Withdrawal
# 1             T2     4507             1554.58   ATM Withdrawal
# 2             T3     1860             2395.02   ATM Withdrawal
# 3             T4     2294              100.10     Bill Payment
# 4             T5     2130             1490.50      POS Payment
#
#    Time_of_Transaction Device_Used       Location  \
# 0                 16.0      Tablet  San Francisco
# 1                 13.0      Mobile       New York
# 2                  NaN      Mobile            NaN
# 3                 15.0     Desktop        Chicago
# 4                 19.0      Mobile  San Francisco
#
#    Previous_Fraudulent_Transactions  Account_Age  \
# 0                                 0          119
# 1                                 4           79
# 2                                 3          115
# 3                                 4            3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51000 entries, 0 to 50999
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Transaction_ID                    51000 non-null  object
#  1   User_ID                           51000 non-null  int64
#  2   Transaction_Amount                48480 non-null  float64
#  3   Transaction_Type                  51000 non-null  object
#  4   Time_of_Transaction               48448 non-null  float64
#  5   Device_Used                       48527 non-null  object
#  6   Location                          48453 non-null  object
#  7   Previous_Fraudulent_Transactions  51000 non-null  int64
#  8   Account_Age                       51000 non-null  int64
#  9   Number_of_Transactions_Last_24H   51000 non-null  int64
#  10  Payment_Method                    48531 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Transaction_ID                         0
# User_ID                                0
# Transaction_Amount                  2520
# Transaction_Type                       0
# Time_of_Transaction                 2552
# Device_Used                         2473
# Location                            2547
# Previous_Fraudulent_Transactions       0
# Account_Age                            0
# Number_of_Transactions_Last_24H        0
# Payment_Method                      2469
# Fraudulent                             0
# dtype: int64

# %% [markdown]
# # Find duplicate data

# %%
dup = df[df.duplicated(subset = 'Transaction_ID')]
dup
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 50000         T33554     2669             2425.71    Bank Transfer
# 50001          T9428     1001             2448.53    Bank Transfer
# 50002           T200     3790             4429.89   ATM Withdrawal
# 50003         T12448     1743              108.00   ATM Withdrawal
# 50004         T39490     4329             2320.30   ATM Withdrawal
# ...              ...      ...                 ...              ...
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 50000                 14.0      Tablet        Seattle
# ...

# %%
transaction_id = input('Enter ur transaction_id:')
data = df[df['Transaction_ID'] == transaction_id]
data
# Out:
# Empty DataFrame
# Columns: [Transaction_ID, User_ID, Transaction_Amount, Transaction_Type, Time_of_Transaction, Device_Used, Location, Previous_Fraudulent_Transactions, Account_Age, Number_of_Transactions_Last_24H, Payment_Method, Fraudulent]
# Index: []

# %%
dup = df.drop_duplicates(subset = 'Transaction_ID',keep ='last')

# %%
dup
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0                 T1     4174             1292.76   ATM Withdrawal
# 1                 T2     4507             1554.58   ATM Withdrawal
# 2                 T3     1860             2395.02   ATM Withdrawal
# 3                 T4     2294              100.10     Bill Payment
# 5                 T6     2095             2372.04   ATM Withdrawal
# ...              ...      ...                 ...              ...
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 0                     16.0      Tablet  San Francisco
# ...

# %%
# To remove unwanted space and records

'''
- strip(),lstrip(),rstrip()
- replace(find, replace_value)   -> for digits and characters
- replace(find, replace_value,  regrex = False)   -> regular expressiona
'''
